# %%
from music21 import * # import everything from music21

# %%
n = note.Note("C#4", quarterLength = 0.5) # create a note object with the pitch C4

# %%
n.show() # show the note object

# %%
n.name
# Out:
# 'C#'

# %%
n2 =n.transpose(5)
n2.nameWithOctave
# Out:
# 'F#4'

# %%
n3 = n2.transpose("m3")
n3.nameWithOctave
# Out:
# 'A4'
