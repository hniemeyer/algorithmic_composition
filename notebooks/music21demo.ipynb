# %%
from music21 import * # import everything from music21
from arvo import tools, isorhythm, minimalism, tintinnabuli
environment.set("musescoreDirectPNGPath", r"C:\Program Files\MuseScore 3\bin\MuseScore3.exe")

# %%
my_score = stream.Stream([
    note.Note("C4", type="half"), note.Note("D4", type="eighth"), note.Note("E4", type="eighth"), note.Note("F4", type="eighth"),
    note.Note("G4", type="eighth"), note.Note("A4"), note.Note("B4"), note.Note("C5"),
])
my_score.show()
my_score.show('midi')
# Out:
#         <div id="midiPlayerDiv146"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv146_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv146");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv146_play, 2000);
#         } else {
#             midiPlayerDiv146_play();
#         }
#         </script>

# %%
my_score.write("midi", fp="my_score.midi")
# Out:
# 'my_score.midi'
