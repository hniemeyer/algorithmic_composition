# %%
from music21 import *

# %%
cMajor = chord.Chord(["C4","E4","G4"])

# %%
cMajor.show()

# %%
cMajor.commonName
# Out:
# 'major triad'

# %%
cMajor.fullName
# Out:
# 'Chord {C in octave 4 | E in octave 4 | G in octave 4} Quarter'

# %%
cMajor.pitchedCommonName
# Out:
# 'C-major triad'

# %%
ivInC = roman.RomanNumeral('IV', key.Key('C'))

# %%
ivInC.pitches
# Out:
# (<music21.pitch.Pitch F4>, <music21.pitch.Pitch A4>, <music21.pitch.Pitch C5>)

# %%
ivInC.show()
