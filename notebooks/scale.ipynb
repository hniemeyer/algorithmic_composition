# %%
from music21 import *

# %%
scale1 = scale.MinorScale("A")
scale1.getPitches("C3","C4")
# Out:
# [<music21.pitch.Pitch C3>,
#  <music21.pitch.Pitch D3>,
#  <music21.pitch.Pitch E3>,
#  <music21.pitch.Pitch F3>,
#  <music21.pitch.Pitch G3>,
#  <music21.pitch.Pitch A3>,
#  <music21.pitch.Pitch B3>,
#  <music21.pitch.Pitch C4>]

# %%
scale2 = scale.MajorScale("A")
scale2.getPitches("C3","C4")
# Out:
# [<music21.pitch.Pitch C#3>,
#  <music21.pitch.Pitch D3>,
#  <music21.pitch.Pitch E3>,
#  <music21.pitch.Pitch F#3>,
#  <music21.pitch.Pitch G#3>,
#  <music21.pitch.Pitch A3>,
#  <music21.pitch.Pitch B3>]

# %%
my_note = note.Note(scale2.getPitches("C3","C4")[1], quarterLength=2)

# %%
my_note.show()
