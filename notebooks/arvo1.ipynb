# %%
from music21 import  *
from arvo import isorhythm
from arvo import minimalism
from arvo import scales
from arvo import transformations

# %%
pitches = ["C4", "D4", "E4", "A4"]
durations = [0.5, 1.0, 1.5, 2.0, 3.5]

# %%
res = isorhythm.create_isorhythm(pitches, durations)

# %%
res.show()

# %%
res.show("midi")
# Out:
#         <div id="midiPlayerDiv554"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv554_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv554");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv554_play, 2000);
#         } else {
#             midiPlayerDiv554_play();
#         }
#         </script>

# %%
pattern_a = minimalism.additive_process(res)

# %%
pattern_a.show()
# Out:
# <p style="padding-top: 20px">&nbsp;</p>

# %%
pattern_a.show("midi")
# Out:
#         <div id="midiPlayerDiv5386"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv5386_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv5386");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv5386_play, 2000);
#         } else {
#             midiPlayerDiv5386_play();
#         }
#         </script>
